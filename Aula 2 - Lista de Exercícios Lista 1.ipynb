# %% [markdown]
# # Aula 2 - Lista de Exercícios Lista 1

# %% [markdown]
# ## 1. Faça um programa que peça ao usuário um número e imprima todos os números de um até o número dado.
# Exemplo: digite: 5, imprime: 1 2 3 4 5

# %%
n = int(input("Digite um número inteiro: "))
i = 1
while i<=n:
    print(i)
    i+=1
# Out:
# Digite um número inteiro: 5
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## 2.  Peça ao usuário para digitar um número n e some todos os números de 1 a n.

# %%
n = int(input("Digite um número inteiro: "))
i = 0
r = 0

while i<=n:
    r+=i
    i+=1
    
print (r)
# Out:
# Digite um número inteiro: 6
# 21

# %% [markdown]
# ## 3. Peça ao usuário para digitar um número e imprima o fatorial de n.

# %%
n = int(input("Digite um número inteiro: "))
i = 1
r = 1

while i<=n:
    r*=i
    i+=1

print (r)
# Out:
# Digite um número inteiro: 7
# 5040

# %% [markdown]
# ## 4. Faça um programa que imprima a tabuada do 9 (de 9*1 a 9*10) usando loops.

# %%
n = int(input("Digite um número inteiro: "))
i = int(input("Digite o primeiro multiplicador desejado: "))
f = int(input("Digite o último multiplicador desejado: "))
r = 0

while i<=f:
    print (n, "x", i,"=",n*i)
    i+=1
# Out:
# Digite um número inteiro: 9
# Digite o primeiro multiplicador desejado: 1
# Digite o último multiplicador desejado: 10
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %% [markdown]
# ### 5. Faça um programa que recebe um número inteiro do usuário e imprime na tela a quantidade de divisores desse número e quais são eles.

# %%
n = int(input("Digite um número inteiro: "))
i = 1
divisores = []

while i<=n:
    r = n%i
    if r == 0:
        divisores.append(i)
        
    i+=1

print ("Quantidade de divisores:",len(divisores))
print ("Divisores:",divisores)
# Out:
# Digite um número inteiro: 19
# Quantidade de divisores: 2
# Divisores: [1, 19]

# %% [markdown]
# ## 6. Faça um programa, usando loops, que peça para um usuário digitar um número e que só finaliza quando o usuário digitar 0. Ao final imprima a soma de todos os números digitados.

# %%
n = int(input("Digite um número inteiro: "))
r = 0
while n!=0:
    r+=n
    n = int(input("Digite outro número inteiro: "))
print (r)
# Out:
# Digite um número inteiro: 6
# Digite outro número inteiro: 2
# Digite outro número inteiro: 2
# Digite outro número inteiro: 1
# Digite outro número inteiro: 0
# 11

# %% [markdown]
# ## 7. Faça um programa que sorteia um número N e peça para o usuário adivinhar o número sorteado. A cada resposta errada, o seu programa deve imprimir um aviso dizendo que a resposta está errada e pedir novamente uma resposta ao usuário.

# %%
import random

sorteado = random.randint(0,10)
n = int(input("Digite um número inteiro entre 0 e 10: "))
tentativa = 1

while n!=sorteado:
    print ("Resposta Incorreta")
    n = int(input("Tente novamente: "))
    tentativa +=1
    
print ("Parabéns você acertou após",tentativa," tentativas. O número sorteado é: ", sorteado)
# Out:
# Digite um número inteiro entre 0 e 10: 8
# Resposta Incorreta
# Tente novamente: 6
# Parabéns você acertou após 2  tentativas. O número sorteado é:  6

# %% [markdown]
# ## 8. Faça um programa que peça para o usuário digitar a idade, o salário e o sexo de uma pessoa até que as entradas digitadas sejam válidas.
# a. Idade: entre 0 e 150;
#
# b. Salário: maior que 0;
#
# c. Sexo: M, F ou Outro.

# %%
idade = 0
salario = 0
genero = ""
while idade <=0 or idade > 150:
    idade = int (input("Digite a sua idade:"))
    if idade <=0 or idade > 150:
        print ("Idade Inválida")

while salario <= 0:
    salario = float(input("Agora digite o seu salário: "))
    if salario <=0:
        print ("Salário Inválido")

while genero != "M" and genero != "F" and genero != "OUTRO":
    genero = input("Qual o seu gênero? ( M / F / Outro)")
    genero = genero.upper()
    if genero != "M" and genero != "F" and genero != "OUTRO":
        print ("Genêro Inválido")
print ("Cadastro efetuado com sucesso")
# Out:
# Digite a sua idade:200
# Idade Inválida
# Digite a sua idade:120
# Agora digite o seu salário: 0
# Salário Inválido
# Agora digite o seu salário: 2
# Qual o seu gênero? ( M / F / Outro)m
# Cadastro efetuado com sucesso
